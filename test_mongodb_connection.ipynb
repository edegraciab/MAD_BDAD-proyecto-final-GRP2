# %% [markdown]
# # Prueba de Conexión a MongoDB
#
# Este notebook prueba la conexión a MongoDB usando PyMongo con la cadena de conexión proporcionada.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Importar las librerías necesarias
import pymongo
from pymongo import MongoClient
import pprint
import json

print("PyMongo version:", pymongo.version)
# Out:
# PyMongo version: 3.12.0

# %% [markdown]
# ## 2. Establish MongoDB Connection

# %%
# Crear la conexión a MongoDB usando la cadena de conexión proporcionada
connection_string = "mongodb+srv://reader12:reader12@educationalcluster.7xf5hht.mongodb.net/"

try:
    # Crear el cliente MongoDB
    client = pymongo.MongoClient(connection_string)
    print("✅ Cliente MongoDB creado exitosamente")
    print(f"Cadena de conexión: {connection_string}")
except Exception as e:
    print(f"❌ Error al crear el cliente: {e}")
# Out:
# ✅ Cliente MongoDB creado exitosamente
# Cadena de conexión: mongodb+srv://reader12:reader12@educationalcluster.7xf5hht.mongodb.net/

# %% [markdown]
# ## 3. Test Database Connection

# %%
# Probar la conexión haciendo ping al servidor
try:
    # Hacer ping al servidor para verificar la conexión
    client.admin.command('ping')
    print("✅ ¡Conexión exitosa! El servidor MongoDB está respondiendo")
    
    # Obtener información del servidor
    server_info = client.server_info()
    print(f"📊 Versión de MongoDB: {server_info['version']}")
    print(f"🖥️  Plataforma: {server_info.get('os', {}).get('name', 'Unknown')}")
    
except Exception as e:
    print(f"❌ Error al conectar con MongoDB: {e}")
# Out:
# ✅ ¡Conexión exitosa! El servidor MongoDB está respondiendo
# 📊 Versión de MongoDB: 8.0.15
# 🖥️  Plataforma: Unknown

# %% [markdown]
# ## 4. List Available Databases

# %%
# Listar las bases de datos disponibles
try:
    database_names = client.list_database_names()
    print(f"📁 Bases de datos disponibles ({len(database_names)}):")
    for i, db_name in enumerate(database_names, 1):
        print(f"   {i}. {db_name}")
    
    # Mostrar información detallada de las bases de datos
    print("\n📋 Información detallada:")
    for db_name in database_names:
        db = client[db_name]
        try:
            collections = db.list_collection_names()
            print(f"   • {db_name}: {len(collections)} colección(es)")
            if collections:
                for collection in collections[:3]:  # Mostrar solo las primeras 3
                    print(f"     - {collection}")
                if len(collections) > 3:
                    print(f"     ... y {len(collections) - 3} más")
        except Exception as e:
            print(f"   • {db_name}: No se puede acceder ({str(e)[:50]}...)")

except Exception as e:
    print(f"❌ Error al listar bases de datos: {e}")
# Out:
# 📁 Bases de datos disponibles (1):
#    1. sample_airbnb
#
# 📋 Información detallada:
#    • sample_airbnb: 4 colección(es)
#      - listings_elements
#      - listings_dimensions
#      - listings_facts
#      ... y 1 más

# %% [markdown]
# ## 5. Test Collection Access

# %%
# Probar el acceso a una colección específica
try:
    # Obtener las bases de datos disponibles
    database_names = client.list_database_names()
    
    if database_names:
        # Usar la primera base de datos disponible (excluyendo las del sistema)
        target_db = None
        for db_name in database_names:
            if db_name not in ['admin', 'local', 'config']:
                target_db = db_name
                break
        
        if target_db:
            print(f"🎯 Probando acceso a la base de datos: {target_db}")
            db = client[target_db]
            collections = db.list_collection_names()
            
            if collections:
                collection_name = collections[0]
                print(f"📄 Probando acceso a la colección: {collection_name}")
                collection = db[collection_name]
                
                # Contar documentos en la colección
                doc_count = collection.count_documents({})
                print(f"📊 Número de documentos en '{collection_name}': {doc_count}")
                
                # Obtener un documento de muestra (si existe)
                if doc_count > 0:
                    sample_doc = collection.find_one()
                    print(f"📋 Documento de muestra:")
                    # Mostrar las primeras claves del documento
                    if isinstance(sample_doc, dict):
                        keys = list(sample_doc.keys())[:5]  # Primeras 5 claves
                        print(f"   Campos: {keys}")
                        if len(sample_doc.keys()) > 5:
                            print(f"   ... y {len(sample_doc.keys()) - 5} campos más")
                else:
                    print("   La colección está vacía")
            else:
                print(f"   La base de datos '{target_db}' no tiene colecciones")
        else:
            print("   Solo se encontraron bases de datos del sistema")
    else:
        print("   No se encontraron bases de datos")

except Exception as e:
    print(f"❌ Error al acceder a colecciones: {e}")
# Out:
# 🎯 Probando acceso a la base de datos: sample_airbnb
# 📄 Probando acceso a la colección: listings_elements
# 📊 Número de documentos en 'listings_elements': 5555
# 📋 Documento de muestra:
#    Campos: ['_id', 'listing_url', 'name', 'property_type', 'room_type']
#    ... y 1 campos más

# %% [markdown]
# ## 6. Verify Connection Status

# %%
# Verificar el estado final de la conexión
try:
    print("🔍 Resumen de la conexión:")
    print(f"   🔗 Estado: Conectado")
    print(f"   🌐 Host: educationalcluster.7xf5hht.mongodb.net")
    print(f"   👤 Usuario: reader123")
    print(f"   🔒 SSL: Habilitado (mongodb+srv)")
    
    # Información adicional del servidor
    server_status = client.admin.command("serverStatus")
    print(f"   ⏰ Tiempo de actividad del servidor: {server_status.get('uptime', 'N/A')} segundos")
    print(f"   🏠 Host del servidor: {server_status.get('host', 'N/A')}")
    
    # Mostrar estadísticas de conexiones
    connections = server_status.get('connections', {})
    print(f"   📊 Conexiones activas: {connections.get('current', 'N/A')}")
    print(f"   📊 Conexiones disponibles: {connections.get('available', 'N/A')}")
    
    print("\n✅ ¡Todas las pruebas completadas exitosamente!")
    
except Exception as e:
    print(f"❌ Error al verificar el estado: {e}")
    
finally:
    # Cerrar la conexión
    try:
        client.close()
        print("\n🔐 Conexión cerrada correctamente")
    except:
        pass
# Out:
# 🔍 Resumen de la conexión:
#    🔗 Estado: Conectado
#    🌐 Host: educationalcluster.7xf5hht.mongodb.net
#    👤 Usuario: reader123
#    🔒 SSL: Habilitado (mongodb+srv)
# ❌ Error al verificar el estado: user is not allowed to do action [serverStatus] on [admin.], full error: {'ok': 0, 'errmsg': 'user is not allowed to do action [serverStatus] on [admin.]', 'code': 8000, 'codeName': 'AtlasError'}
#
# 🔐 Conexión cerrada correctamente

# %%
# Seleccionamos base de datos y colección
db = client["sample_airbnb"]
collection = db["listingsAndReviews"]

# %%
# --- EXTRACT ---
# Extraemos todos los documentos de la colección
docs = list(collection.find())

# %%
# --- TRANSFORM ---
# 1. CSV: solo campos descriptivos y metadatos elementales de cada propiedad
elemental_keys = [
  "_id",
  "listing_url",
  "name",
  "property_type",
  "room_type",
  "bed_type"
]

csv_rows = []
for doc in docs:
    filtered = {"_id": str(doc["_id"])}
    for key in elemental_keys:
        if key in doc and key != "_id":
            filtered[key] = doc[key]
    csv_rows.append(filtered)

# 2. Dimensiones: objetos/arrays descriptivos (atributos estáticos)
dimension_keys = [
  "summary",
  "space",
  "description",
  "neighborhood_overview",
  "notes",
  "transit",
  "access",
  "interaction",
  "house_rules",
  "minimum_nights",
  "maximum_nights",
  "cancellation_policy",
  "amenities",
  "images",
  "host",
  "address",
]

dimension_docs = []
for doc in docs:
    filtered = {"_id": str(doc["_id"])}
    for key in dimension_keys:
        if key in doc:
            filtered[key] = doc[key]
    dimension_docs.append(filtered)

# 3. Hechos: métricas y eventos dinámicos (cambian con el tiempo)
fact_keys = [
  "last_scraped",
  "calendar_last_scraped",
  "first_review",
  "last_review",
  "accommodates",
  "bedrooms",
  "beds",
  "bathrooms",
  "number_of_reviews",
  "price",
  "security_deposit",
  "cleaning_fee",
  "extra_people",
  "guests_included",
  "availability",
  "review_scores",
  "reviews"
]

fact_docs = []
for doc in docs:
    filtered = {"_id": str(doc["_id"])}
    for key in fact_keys:
        if key in doc:
            filtered[key] = doc[key]
    fact_docs.append(filtered)

# %%
import json
import pandas as pd
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from bson import json_util

# %%
# --- LOAD ---
# Guardamos CSV con atributos escalares
df = pd.DataFrame(csv_rows)
df
# Out:
#            _id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name property_type  \
# 0                               Ribeira Charming Duplex         House
# 1                          Horto flat with small garden     Apartment
# 2                      Ocean View Waikiki Marina w/prkg   Condominium
# ...
